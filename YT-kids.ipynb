# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import time
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
import time
import pandas as pd
import datetime 


# headless background execution
Options = Options()
Options.headless = True

# %%
age = 1 ### 1 ,2 ,3 correspond to the 3 age groups

# %%
url = "https://www.youtubekids.com/?hl=en-GB"
browser = webdriver.Chrome(ChromeDriverManager().install())
browser.get(url)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [/Users/danhagen/.wdm/drivers/chromedriver/mac64/103.0.5060.53/chromedriver] found in cache
# /var/folders/xt/gl55xsd51h13q_107rrh98640000gn/T/ipykernel_93748/1454790625.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(ChromeDriverManager().install())

# %%
browser.title
# Out:
# 'YouTube Kids'

# %%
browser.implicitly_wait(20)
search =  browser.find_element(By.ID, "parent-button")
search.send_keys(Keys.ENTER)
next_butt =browser.find_element(By.ID, "next-button")
next_butt.send_keys(Keys.ENTER)
one = browser.find_element(By.ID, "onboarding-age-gate-digit-1")
two = browser.find_element(By.ID, "onboarding-age-gate-digit-2")
three = browser.find_element(By.ID, "onboarding-age-gate-digit-3")
fore = browser.find_element(By.ID, "onboarding-age-gate-digit-4")
one.send_keys(1)
two.send_keys(9)
three.send_keys(9)
fore.send_keys(9)
actions = ActionChains(browser) 
actions.send_keys(Keys.TAB*7)
actions.perform()
actions.send_keys(Keys.ENTER)
actions.perform()
counter = 0

def click():
    time.sleep(3)

    submit = browser.find_element(By.ID, "sign-in-info-next-button")
    try:
        submit.send_keys(Keys.ENTER)
        return(0)
    except Exception:
        click()

        
click()
submit = browser.find_element(By.ID, "skip-button")
submit.send_keys(Keys.ENTER)
actions = ActionChains(browser) 
actions.send_keys(Keys.TAB*5)
actions.perform()
actions.send_keys(Keys.ENTER)
actions.perform()
actions = ActionChains(browser) 
actions.send_keys(Keys.TAB*age)
actions.perform()
actions.send_keys(Keys.ENTER)
actions.perform()
browser.implicitly_wait(20)

# %%
def press():
    time.sleep(1)

    try:
        submit = browser.find_element(By.ID, "select-link")
        submit.send_keys(Keys.ENTER)
        return(0)
    except Exception:
        press()

press()
submit = browser.find_element(By.ID, "search-on-button")
submit.send_keys(Keys.ENTER)
submit = browser.find_element(By.ID, "done-button")
submit.send_keys(Keys.ENTER)

# %%
listele = browser.find_elements(By.CLASS_NAME, "style-scope ytk-compact-video-renderer")
show_title_1=[]
show_link_1 =[]

for item in listele:
    a = item.get_attribute("innerHTML")
    show_link_1.append("www.youtubekids.com"+ a.split('href="')[1].split('">')[0])
    show_title_1.append(a.split("aria-label=")[1].split("title")[0].split("Video")[1].split('"')[0])
    
listele_time = browser.find_elements(By.CLASS_NAME, "overlay style-scope ytk-compact-video-rendere")

show_lenght_1=[]
for item in listele:
    a = item.get_attribute("innerHTML").split('renderer">')[2].split("</span")[0]
    show_lenght_1.append(a)

# %%
actions = ActionChains(browser) 
actions.send_keys(Keys.TAB*7)
actions.perform()
actions.send_keys(Keys.ENTER)
actions.perform()

# %%
listele = browser.find_elements(By.CLASS_NAME, "style-scope ytk-compact-video-renderer")
music_title_1=[]
music_link_1 =[]

for item in listele:
    a = item.get_attribute("innerHTML")
    music_link_1.append("www.youtubekids.com"+ a.split('href="')[1].split('">')[0])
    music_title_1.append(a.split("aria-label=")[1].split("title")[0].split("Video")[1].split('"')[0])
    
listele_time = browser.find_elements(By.CLASS_NAME, "overlay style-scope ytk-compact-video-rendere")

music_lenght_1=[]
for item in listele:
    a = item.get_attribute("innerHTML").split('renderer">')[2].split("</span")[0]
    music_lenght_1.append(a)

# %%
actions = ActionChains(browser) 
actions.send_keys(Keys.TAB*78)
actions.perform()
actions.send_keys(Keys.ENTER)
actions.perform()
time.sleep(1)

# %%
listele = browser.find_elements(By.CLASS_NAME, "style-scope ytk-compact-video-renderer")
learning_title_1=[]
learning_link_1 =[]
for item in listele:
    a = item.get_attribute("innerHTML")
    learning_link_1.append("www.youtubekids.com"+ a.split('href="')[1].split('">')[0])
    learning_title_1.append(a.split("aria-label=")[1].split("title")[0].split("Video")[1].split('"')[0])
    
listele_time = browser.find_elements(By.CLASS_NAME, "overlay style-scope ytk-compact-video-rendere")

learning_lenght_1=[]
for item in listele:
    a = item.get_attribute("innerHTML").split('renderer">')[2].split("</span")[0]
    learning_lenght_1.append(a)

# %%
actions = ActionChains(browser) 
actions.send_keys(Keys.TAB*80)
actions.perform()
actions.send_keys(Keys.ENTER)
actions.perform()
time.sleep(1)

# %%
listele = browser.find_elements(By.CLASS_NAME, "style-scope ytk-compact-video-renderer")
explore_title_1=[]
explore_link_1 =[]

for item in listele:
    a = item.get_attribute("innerHTML")
    explore_link_1.append("www.youtubekids.com"+ a.split('href="')[1].split('">')[0])
    explore_title_1.append(a.split("aria-label=")[1].split("title")[0].split("Video")[1].split('"')[0])
    
listele_time = browser.find_elements(By.CLASS_NAME, "overlay style-scope ytk-compact-video-rendere")

explore_lenght_1=[]
for item in listele:
    a = item.get_attribute("innerHTML").split('renderer">')[2].split("</span")[0]
    explore_lenght_1.append(a)

# %%
theme_1 = []
theme_1 += ["shows"]*len(show_title_1)
theme_1 += ["music"]*len(music_title_1)
theme_1 += ["learning"]*len(learning_title_1)
theme_1 += ["explore"]*len(explore_title_1)


title_1=[]
title_1 += show_title_1
title_1 += music_title_1
title_1 += learning_title_1
title_1 += explore_title_1


lenght_1=[]
lenght_1 += show_lenght_1
lenght_1 += music_lenght_1
lenght_1 += learning_lenght_1
lenght_1 += explore_lenght_1

link_1 =[]
link_1 += show_link_1
link_1 += music_link_1
link_1 += learning_link_1
link_1 += explore_link_1

browser.close()

# %% [markdown]
# # Age 2

# %%
url = "https://www.youtubekids.com/?hl=en-GB"
browser = webdriver.Chrome(ChromeDriverManager().install())
browser.get(url)

age =2

browser.implicitly_wait(20)

search =  browser.find_element(By.ID, "parent-button")
search.send_keys(Keys.ENTER)
next_butt =browser.find_element(By.ID, "next-button")
next_butt.send_keys(Keys.ENTER)
one = browser.find_element(By.ID, "onboarding-age-gate-digit-1")
two = browser.find_element(By.ID, "onboarding-age-gate-digit-2")
three = browser.find_element(By.ID, "onboarding-age-gate-digit-3")
fore = browser.find_element(By.ID, "onboarding-age-gate-digit-4")
one.send_keys(1)
two.send_keys(9)
three.send_keys(9)
fore.send_keys(9)
actions = ActionChains(browser) 
actions.send_keys(Keys.TAB*7)
actions.perform()
actions.send_keys(Keys.ENTER)
actions.perform()
counter = 0

def click():
    time.sleep(3)
    submit = browser.find_element(By.ID, "sign-in-info-next-button")
    try:
        submit.send_keys(Keys.ENTER)
        return(0)
    except Exception:
        click()

        
click()
submit = browser.find_element(By.ID, "skip-button")
submit.send_keys(Keys.ENTER)
actions = ActionChains(browser) 
actions.send_keys(Keys.TAB*5)
actions.perform()
actions.send_keys(Keys.ENTER)
actions.perform()
actions = ActionChains(browser) 
actions.send_keys(Keys.TAB*age)
actions.perform()
actions.send_keys(Keys.ENTER)
actions.perform()
browser.implicitly_wait(20)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [/Users/danhagen/.wdm/drivers/chromedriver/mac64/103.0.5060.53/chromedriver] found in cache
# /var/folders/xt/gl55xsd51h13q_107rrh98640000gn/T/ipykernel_93748/401610516.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(ChromeDriverManager().install())

# %%
def press():
    try:
        submit = browser.find_element(By.ID, "select-link")
        submit.send_keys(Keys.ENTER)
        return(0)
    except Exception:
        press()

press()
submit = browser.find_element(By.ID, "search-on-button")
submit.send_keys(Keys.ENTER)
submit = browser.find_element(By.ID, "done-button")
submit.send_keys(Keys.ENTER)

# %%
listele = browser.find_elements(By.CLASS_NAME, "style-scope ytk-compact-video-renderer")
show_title_2=[]
show_link_2 =[]
for item in listele:
    a = item.get_attribute("innerHTML")
    show_link_2.append("www.youtubekids.com"+ a.split('href="')[1].split('">')[0])
    show_title_2.append(a.split("aria-label=")[1].split("title")[0].split("Video")[1].split('"')[0])
    
listele_time = browser.find_elements(By.CLASS_NAME, "overlay style-scope ytk-compact-video-rendere")

show_lenght_2=[]
for item in listele:
    a = item.get_attribute("innerHTML").split('renderer">')[2].split("</span")[0]
    show_lenght_2.append(a)

# %%
actions = ActionChains(browser) 
actions.send_keys(Keys.TAB*7)
actions.perform()
actions.send_keys(Keys.ENTER)
actions.perform()

# %%
listele = browser.find_elements(By.CLASS_NAME, "style-scope ytk-compact-video-renderer")
music_title_2=[]
music_link_2 =[]
for item in listele:
    a = item.get_attribute("innerHTML")
    music_link_2.append("www.youtubekids.com"+ a.split('href="')[1].split('">')[0])
    music_title_2.append(a.split("aria-label=")[1].split("title")[0].split("Video")[1].split('"')[0])
    
listele_time = browser.find_elements(By.CLASS_NAME, "overlay style-scope ytk-compact-video-rendere")

music_lenght_2=[]
for item in listele:
    a = item.get_attribute("innerHTML").split('renderer">')[2].split("</span")[0]
    music_lenght_2.append(a)

# %%
actions = ActionChains(browser) 
actions.send_keys(Keys.TAB*78)
actions.perform()
actions.send_keys(Keys.ENTER)
actions.perform()

# %%
time.sleep(1)

# %%
listele = browser.find_elements(By.CLASS_NAME, "style-scope ytk-compact-video-renderer")
learning_title_2=[]
learning_link_2 = []
for item in listele:
    a = item.get_attribute("innerHTML")
    learning_link_2.append("www.youtubekids.com"+ a.split('href="')[1].split('">')[0])
    learning_title_2.append(a.split("aria-label=")[1].split("title")[0].split("Video")[1].split('"')[0])
    
listele_time = browser.find_elements(By.CLASS_NAME, "overlay style-scope ytk-compact-video-rendere")

learning_lenght_2=[]
for item in listele:
    a = item.get_attribute("innerHTML").split('renderer">')[2].split("</span")[0]
    learning_lenght_2.append(a)

# %%
time.sleep(1)

# %%
actions = ActionChains(browser) 
actions.send_keys(Keys.TAB*80)
actions.perform()
actions.send_keys(Keys.ENTER)
actions.perform()

# %%
listele = browser.find_elements(By.CLASS_NAME, "style-scope ytk-compact-video-renderer")
explore_title_2=[]
explore_link_2 =[]

for item in listele:
    a = item.get_attribute("innerHTML")
    explore_link_2.append("www.youtubekids.com"+ a.split('href="')[1].split('">')[0])
    explore_title_2.append(a.split("aria-label=")[1].split("title")[0].split("Video")[1].split('"')[0])
    
listele_time = browser.find_elements(By.CLASS_NAME, "overlay style-scope ytk-compact-video-rendere")

explore_lenght_2=[]
for item in listele:
    a = item.get_attribute("innerHTML").split('renderer">')[2].split("</span")[0]
    explore_lenght_2.append(a)

# %%
theme_2 = []
theme_2 += ["shows"]*len(show_title_2)
theme_2 += ["music"]*len(music_title_2)
theme_2 += ["learning"]*len(learning_title_2)
theme_2 += ["explore"]*len(explore_title_2)

title_2=[]
title_2 += show_title_2
title_2 += music_title_2
title_2 += learning_title_2
title_2 += explore_title_2


lenght_2=[]
lenght_2 += show_lenght_2
lenght_2 += music_lenght_2
lenght_2 += learning_lenght_2
lenght_2 += explore_lenght_2

link_2 =[]
link_2 += show_link_2
link_2 += music_link_2
link_2 += learning_link_2
link_2 += explore_link_2

browser.close()

# %% [markdown]
# # Age 3

# %%
url = "https://www.youtubekids.com/?hl=en-GB"
browser = webdriver.Chrome(ChromeDriverManager().install())
browser.get(url)

age =3

browser.implicitly_wait(20)

search =  browser.find_element(By.ID, "parent-button")
search.send_keys(Keys.ENTER)
next_butt =browser.find_element(By.ID, "next-button")
next_butt.send_keys(Keys.ENTER)
one = browser.find_element(By.ID, "onboarding-age-gate-digit-1")
two = browser.find_element(By.ID, "onboarding-age-gate-digit-2")
three = browser.find_element(By.ID, "onboarding-age-gate-digit-3")
fore = browser.find_element(By.ID, "onboarding-age-gate-digit-4")
one.send_keys(1)
two.send_keys(9)
three.send_keys(9)
fore.send_keys(9)
actions = ActionChains(browser) 
actions.send_keys(Keys.TAB*7)
actions.perform()
actions.send_keys(Keys.ENTER)
actions.perform()
counter = 0

def click():
    time.sleep(3)

    submit = browser.find_element(By.ID, "sign-in-info-next-button")
    try:
        submit.send_keys(Keys.ENTER)
        return(0)
    except Exception:
        click()

        
click()
submit = browser.find_element(By.ID, "skip-button")
submit.send_keys(Keys.ENTER)
actions = ActionChains(browser) 
actions.send_keys(Keys.TAB*5)
actions.perform()
actions.send_keys(Keys.ENTER)
actions.perform()
actions = ActionChains(browser) 
actions.send_keys(Keys.TAB*age)
actions.perform()
actions.send_keys(Keys.ENTER)
actions.perform()
browser.implicitly_wait(20)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - Driver [/Users/danhagen/.wdm/drivers/chromedriver/mac64/103.0.5060.53/chromedriver] found in cache
# /var/folders/xt/gl55xsd51h13q_107rrh98640000gn/T/ipykernel_93748/2610634597.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(ChromeDriverManager().install())

# %%
def press():
    try:
        submit = browser.find_element(By.ID, "select-link")
        submit.send_keys(Keys.ENTER)
        return(0)
    except Exception:
        press()

press()
submit = browser.find_element(By.ID, "search-on-button")
submit.send_keys(Keys.ENTER)
submit = browser.find_element(By.ID, "done-button")
submit.send_keys(Keys.ENTER)

# %%
listele = browser.find_elements(By.CLASS_NAME, "style-scope ytk-compact-video-renderer")
show_title_3=[]
show_link_3 =[]
for item in listele:
    a = item.get_attribute("innerHTML")
    show_link_3.append("www.youtubekids.com"+ a.split('href="')[1].split('">')[0])
    show_title_3.append(a.split("aria-label=")[1].split("title")[0].split("Video")[1].split('"')[0])
    
listele_time = browser.find_elements(By.CLASS_NAME, "overlay style-scope ytk-compact-video-rendere")

show_lenght_3=[]
for item in listele:
    a = item.get_attribute("innerHTML").split('renderer">')[2].split("</span")[0]
    show_lenght_3.append(a)

# %%
actions = ActionChains(browser) 
actions.send_keys(Keys.TAB*7)
actions.perform()
actions.send_keys(Keys.ENTER)
actions.perform()

# %%
listele = browser.find_elements(By.CLASS_NAME, "style-scope ytk-compact-video-renderer")
music_title_3=[]
music_link_3 =[]
for item in listele:
    a = item.get_attribute("innerHTML")
    music_link_3.append("www.youtubekids.com"+ a.split('href="')[1].split('">')[0])
    music_title_3.append(a.split("aria-label=")[1].split("title")[0].split("Video")[1].split('"')[0])
    
listele_time = browser.find_elements(By.CLASS_NAME, "overlay style-scope ytk-compact-video-rendere")

music_lenght_3=[]
for item in listele:
    a = item.get_attribute("innerHTML").split('renderer">')[2].split("</span")[0]
    music_lenght_3.append(a)

# %%
actions = ActionChains(browser) 
actions.send_keys(Keys.TAB*78)
actions.perform()
actions.send_keys(Keys.ENTER)
actions.perform()

# %%
time.sleep(1)

# %%
listele = browser.find_elements(By.CLASS_NAME, "style-scope ytk-compact-video-renderer")
learning_title_3=[]
learning_link_3 =[]
for item in listele:
    a = item.get_attribute("innerHTML")
    learning_link_3.append("www.youtubekids.com"+ a.split('href="')[1].split('">')[0])
    learning_title_3.append(a.split("aria-label=")[1].split("title")[0].split("Video")[1].split('"')[0])
    
listele_time = browser.find_elements(By.CLASS_NAME, "overlay style-scope ytk-compact-video-rendere")

learning_lenght_3=[]
for item in listele:
    a = item.get_attribute("innerHTML").split('renderer">')[2].split("</span")[0]
    learning_lenght_3.append(a)

# %%
actions = ActionChains(browser) 
actions.send_keys(Keys.TAB*80)
actions.perform()
actions.send_keys(Keys.ENTER)
actions.perform()

# %%
time.sleep(1)

# %%
listele = browser.find_elements(By.CLASS_NAME, "style-scope ytk-compact-video-renderer")
explore_title_3=[]
explore_link_3 = []
for item in listele:
    a = item.get_attribute("innerHTML")
    explore_link_3.append("www.youtubekids.com"+ a.split('href="')[1].split('">')[0])
    explore_title_3.append(a.split("aria-label=")[1].split("title")[0].split("Video")[1].split('"')[0])
    
listele_time = browser.find_elements(By.CLASS_NAME, "overlay style-scope ytk-compact-video-rendere")

explore_lenght_3=[]
for item in listele:
    a = item.get_attribute("innerHTML").split('renderer">')[2].split("</span")[0]
    explore_lenght_3.append(a)

# %%
theme_3 = []
theme_3 += ["shows"]*len(show_title_3)
theme_3 += ["music"]*len(music_title_3)
theme_3 += ["explore"]*len(learning_title_3)
theme_3 += ["gaming"]*len(explore_title_3)

title_3=[]
title_3 += show_title_3
title_3 += music_title_3
title_3 += learning_title_3
title_3 += explore_title_3


lenght_3=[]
lenght_3 += show_lenght_3
lenght_3 += music_lenght_3
lenght_3 += learning_lenght_3
lenght_3 += explore_lenght_3


link_3 =[]
link_3 += show_link_3
link_3 += music_link_3
link_3 += learning_link_3
link_3 += explore_link_3

# %%
final_title =[]
final_title +=(title_1)
final_title +=(title_2)
final_title += (title_3)

final_lenght = []
final_lenght +=(lenght_1)
final_lenght +=(lenght_2)
final_lenght +=(lenght_3)


final_theme =[]
final_theme +=(theme_1)
final_theme +=(theme_2)
final_theme +=(theme_3)

today = str(datetime.datetime.today())[:10]
date = [today]*len(final_lenght)

age = [1]*len(title_1)
age += [2]* len(title_2)
age += [3]*len(title_3)

final_link = []
final_link +=(link_1)
final_link +=(link_2)
final_link +=(link_3)



browser.close()

# %%
df = pd.DataFrame(({'Title' : final_title,'Video link' : final_link, 'Video lenght' : final_lenght , 
                    'Date': date, 'Age group': age, 'Theme': final_theme}))

# %%
df.head(20)
# Out:
#                                                 Title  \
# 0    De Kippen Van Oma Big | Speciale Aflevering |...
# 1    Caillou op de fiets | Caillou Nederlands - Wi...
# 2    helemaal anders | nijntje | kindertelevisie |...
# 3    Teletubbies: 1 UUR Compilatie 🇳🇱 | Beste Tele...
# 4    Peppa Pig English Episodes | Vegetables for G...
# 5    The Boo Boo Song Nursery Rhymes and Kids Song...
# 6    Painting with Hands and Potatoes with Peppa P...
# 7    Teletubbies: 2 HOUR Compilation | Season 16, ...
# 8    Learn Letters, Chain Reactions, Physics, Recy...
# 9    Peppa Pig English Episodes | Mummy Rabbit's B...
# 10   Ice Cream Islands for Kids with Steve and Mag...
# 11   Masha and the Bear 🎬💥 LIVE STREAM 💥🎬 Cartoon ...
# 12   PAW Patrol Rescues &amp; Healthy Habits! w/ C...
# 13   Play Kids Game with Steve and Maggie | Best S...
# 14   Head, Shoulders Knees and Toes and more Nurse...
# 15   Masha and the Bear 💖🎂 Chocolate Cupcake Day 🎂...
# ...

# %%
df.to_csv('YT-Kids.csv', mode='a', index=False, header=False)
